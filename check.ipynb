# %%
import pandas as pd

# %%
print(pd.read_csv("ic50_large_dataset.csv").head().columns)
# Out:
# Index(['disease_name', 'efo_id', 'target_id', 'target_symbol',
#        'association_score', 'drug_id', 'drug_name', 'clinical_phase',
#        'ic50_value', 'ic50_units', 'target_chembl_id', 'assay_chembl_id',
#        'pchembl_value', 'chembl_id', 'max_phase', 'molecular_formula',
#        'molecular_weight', 'alogp', 'aromatic_rings', 'mw_freebase', 'hba',
#        'hbd', 'heavy_atoms', 'np_likeness_score', 'num_ro5_violations', 'psa',
#        'qed_weighted', 'ro3_pass', 'rtb', 'smiles', 'inchi', 'inchi_key',
#        'molfile_preview'],
#       dtype='object')
